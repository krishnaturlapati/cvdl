# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnaturlapati/cvdl/blob/main/cv_contour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import numpy as np
import cv2

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['image.png']))
# Out:
#      <input type="file" id="files-339d2b16-c629-4b32-a531-8b84f5dcc413" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-339d2b16-c629-4b32-a531-8b84f5dcc413">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png

# %%
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()

# %%
# Using cv2.imread() method
img = cv2.imread('image.png')

# %%
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook

import cv2
from matplotlib import pyplot as plt

#Import image
image = cv2.imread("image.png")

#Show the image with matplotlib
plt.imshow(image)
plt.show()

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
twoDimage = img.reshape((-1,3))
twoDimage = np.float32(twoDimage)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 
attempts=10

# %%
ret,label,center=cv2.kmeans(twoDimage,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

# %%
plt.imshow(result_image)
plt.show()

# %%
#

# %% [markdown]
# Contour

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
path = 'image.png'
img = cv2.imread(path)
img = cv2.resize(img,(256,256))

# %%
gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
_,thresh = cv2.threshold(gray, np.mean(gray), 255, cv2.THRESH_BINARY_INV)
edges = cv2.dilate(cv2.Canny(thresh,0,255),None)

# %%
plt.imshow(edges)
plt.show()

# %%
cnt = sorted(cv2.findContours(edges, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2], key=cv2.contourArea)[-1]
mask = np.zeros((256,256), np.uint8)
masked = cv2.drawContours(mask, [cnt],-1, 255, -1)

# %%
dst = cv2.bitwise_and(img, img, mask=mask)
segmented = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(segmented)
plt.show()

# %% [markdown]
# Another article

# %%
image = cv2.imread('image.png')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots(1, figsize=(12,8))
plt.imshow(image)

# %%
g = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
edge = cv2.Canny(g, 60, 180)
fig, ax = plt.subplots(1, figsize=(12,8))
plt.imshow(edge, cmap='Greys')

# %%
contours = cv2.findContours(edge, 
                            cv2.RETR_EXTERNAL,
                            cv2.CHAIN_APPROX_NONE)
cv2.drawContours(image, contours[0], -1, (0,0,255), thickness = 2)
fig, ax = plt.subplots(1, figsize=(12,8))
plt.imshow(image)

# %% [markdown]
# Neural Network
